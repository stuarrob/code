# %% [markdown]
# # ETF Analysis Pipeline
#
# Runs the full analysis pipeline via thin wrappers over `notebooks/scripts/s1-s6`.
#
# | Section | Script | Description |
# |---------|--------|-------------|
# | 0 | - | Setup & Configuration |
# | 1 | s1_universe | Universe Discovery (~5,000 ETFs) |
# | 2 | s2_collect | Historical Data Collection (IB + yfinance) |
# | 3 | s3_factors | Factor Scoring (Mom/Qual/Val/Vol) |
# | 4 | s4_optimize | Portfolio Construction |
# | 5 | s5_backtest | Backtesting |
# | 6 | s6_trades | Trade Recommendations |
#
# Output: `~/trading/live_portfolio/trade_plan.csv` → used by `02_execute_trades.ipynb`

# %% [markdown]
# ---
# ## Section 0: Setup

# %%
import sys
import warnings
from pathlib import Path

import nest_asyncio
nest_asyncio.apply()
warnings.filterwarnings("ignore")

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))
sys.path.insert(0, str(PROJECT_ROOT / "notebooks"))

DATA_DIR = Path.home() / "trade_data" / "ETFTrader"
RAW_DIR = DATA_DIR / "raw"
PROCESSED_DIR = DATA_DIR / "processed"
IB_CACHE_DIR = DATA_DIR / "ib_historical"
LIVE_DIR = Path.home() / "trading" / "live_portfolio"

for d in [PROCESSED_DIR, LIVE_DIR, IB_CACHE_DIR]:
    d.mkdir(parents=True, exist_ok=True)

# ── Strategy parameters ──────────────────────────────────
# Factor weights (value auto-skipped if no expense data)
FACTOR_WEIGHTS = {
    "momentum": 0.35, "quality": 0.30,
    "value": 0.15, "volatility": 0.20,
}
NUM_POSITIONS = 30           # 30 positions per backtest recommendation
OPTIMIZER_TYPE = "mvo"       # "mvo" (recommended, robust) | "rankbased" | "minvar"
REBALANCE_FREQ = "quarterly" # "quarterly" | "bimonthly" | "monthly"

# IB settings
IB_HOST = "127.0.0.1"
IB_PORT = 4001
IB_CLIENT_ID = 5

print(f"Data:       {DATA_DIR}")
print(f"Output:     {LIVE_DIR}")
print(f"Positions:  {NUM_POSITIONS}")
print(f"Optimizer:  {OPTIMIZER_TYPE}")
print(f"Rebalance:  {REBALANCE_FREQ}")
# Out:
# Data:       /home/stuar/trade_data/ETFTrader
# Output:     /home/stuar/trading/live_portfolio
# Positions:  30
# Optimizer:  mvo
# Rebalance:  quarterly

# %% [markdown]
# ---
# ## Section 1: Universe Discovery

# %%
from scripts.s1_universe import discover_universe

all_tickers, categories, universe_df = discover_universe(PROJECT_ROOT)
print(f"Universe: {len(all_tickers)} ETFs")
# Out:
# Full universe: 5042 ETFs
#   Categorized (curated):  792
#   Uncategorized (NASDAQ): 4250
#   Leveraged/inverse:      75 (kept for data collection)
# Universe: 5042 ETFs

# %% [markdown]
# ---
# ## Section 2: Data Collection
#
# Set `RUN_COLLECTION = True` to connect to IB Gateway.

# %%
RUN_COLLECTION = False  # Set True to connect to IB

from scripts.s2_collect import collect_data, apply_quality_filter

prices = collect_data(
    tickers=all_tickers,
    ib_cache_dir=IB_CACHE_DIR,
    processed_dir=PROCESSED_DIR,
    ib_host=IB_HOST, ib_port=IB_PORT, ib_client_id=IB_CLIENT_ID,
    run_collection=RUN_COLLECTION,
)

if prices is not None:
    prices = apply_quality_filter(prices)
    print(f"Prices: {prices.shape[1]} tickers x {prices.shape[0]} days")
# Out:
# Loaded IB prices: 3801 tickers x 1256 days
#   Range: 2021-02-16 to 2026-02-13
# Connected to IB: U9544585
#
#   ============================================================
#   DATA COLLECTION — scanning cache...
#   ============================================================
#
#   Universe: 5042 tickers
#     CURRENT (up-to-date, skip):    0
#     STALE (incremental update):     4953
#     MISSING (full 5Y download):     89
#
#   Stale tickers to update:
#       AAAA   last: 2026-02-13  gap: 2d
#       AAAC   last: 2026-02-13  gap: 2d
#       AAAU   last: 2026-02-13  gap: 2d
#       AADR   last: 2026-02-13  gap: 2d
#       AAEQ   last: 2026-02-13  gap: 2d
#       AALG   last: 2026-02-13  gap: 2d
#       AAPB   last: 2026-02-13  gap: 2d
#       AAPD   last: 2026-02-13  gap: 2d
#       AAPR   last: 2026-02-13  gap: 2d
#       AAPU   last: 2026-02-13  gap: 2d
#       AAPW   last: 2026-02-13  gap: 2d
#       AAPX   last: 2026-02-13  gap: 2d
#       AAPY   last: 2026-02-13  gap: 2d
#       AAUM   last: 2026-02-13  gap: 2d
#       AAUS   last: 2026-02-13  gap: 2d
#       AAVM   last: 2026-02-13  gap: 2d
#       AAXJ   last: 2026-02-13  gap: 2d
#       ABCS   last: 2026-02-13  gap: 2d
#       ABEQ   last: 2026-02-13  gap: 2d
#       ABFL   last: 2026-02-13  gap: 2d
#       ... and 4933 more
#
#   [22:07:39] Qualifying 5042 contracts on IB...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 RUN_COLLECTION = True  # Set True to connect to IB
#       3 from scripts.s2_collect import collect_data, apply_quality_filter
# ----> 5 prices = collect_data(
#       6     tickers=all_tickers,
#       7     ib_cache_dir=IB_CACHE_DIR,
#       8     processed_dir=PROCESSED_DIR,
#       9     ib_host=IB_HOST, ib_port=IB_PORT, ib_client_id=IB_CLIENT_ID,
#      10     run_collection=RUN_COLLECTION,
#      11 )
#      13 if prices is not None:
#      14     prices = apply_quality_filter(prices)
#
# File ~/code/ETFTrader/notebooks/scripts/s2_collect.py:79, in collect_data(tickers, ib_cache_dir, processed_dir, ib_host, ib_port, ib_client_id, run_collection)
#      70     print(f"Connected to IB: {ib.managedAccounts()[0]}\n")
#      72     collector = IBDataCollector(
#      73         ib=ib,
#      74         cache_dir=str(ib_cache_dir),
#      75         rate_limit_interval=12.0,
#      76         duration="5 Y",
#      77     )
# ---> 79     prices, results = collector.collect_universe(tickers)
#      80     ib.disconnect()
#      82 except Exception as e:
#
# File ~/code/ETFTrader/src/data_collection/ib_data_collector.py:393, in IBDataCollector.collect_universe(self, tickers, progress_callback, max_consecutive_failures)
#     391 need_work = [t for t, _, _ in stale_tickers] + missing_tickers
#     392 self._log(f"Qualifying {len(need_work)} contracts on IB...")
# --> 393 qualified, qual_failed = self.qualify_contracts(need_work)
#     394 self._log(
#     395     f"Qualified: {len(qualified)}, "
#     396     f"Failed: {len(qual_failed)}"
#     397 )
#     398 if qual_failed:
#
# File ~/code/ETFTrader/src/data_collection/ib_data_collector.py:87, in IBDataCollector.qualify_contracts(self, tickers, batch_size)
#      85 c = Stock(t, "SMART", "USD")
#      86 try:
# ---> 87     self.ib.qualifyContracts(c)
#      88     if c.conId:
#      89         qualified.append(c)
#
# File ~/code/ETFTrader/venv/lib/python3.12/site-packages/ib_insync/ib.py:570, in IB.qualifyContracts(self, *contracts)
#     558 def qualifyContracts(self, *contracts: Contract) -> List[Contract]:
#     559     """
#     560     Fully qualify the given contracts in-place. This will fill in
#     561     the missing fields in the contract, especially the conId.
#    (...)    568         contracts: Contracts to qualify.
#     569     """
# --> 570     return self._run(self.qualifyContractsAsync(*contracts))
#
# File ~/code/ETFTrader/venv/lib/python3.12/site-packages/ib_insync/ib.py:318, in IB._run(self, *awaitables)
#     317 def _run(self, *awaitables: Awaitable):
# --> 318     return util.run(*awaitables, timeout=self.RequestTimeout)
#
# File ~/code/ETFTrader/venv/lib/python3.12/site-packages/ib_insync/util.py:341, in run(timeout, *awaitables)
#     339 globalErrorEvent.connect(onError)
#     340 try:
# --> 341     result = loop.run_until_complete(task)
#     342 except asyncio.CancelledError as e:
#     343     raise globalErrorEvent.value() or e
#
# File ~/code/ETFTrader/venv/lib/python3.12/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/code/ETFTrader/venv/lib/python3.12/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File /usr/lib/python3.12/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# ## Section 3: Factor Scoring

# %%
from scripts.s3_factors import score_factors

combined_scores, prices_basic, factor_detail = score_factors(
    prices, factor_weights=FACTOR_WEIGHTS,
    categories=categories, raw_dir=RAW_DIR,
)
print(f"Scores: {len(combined_scores)} tickers")
combined_scores.nlargest(20)

# %% [markdown]
# ---
# ## Section 4: Portfolio Construction

# %%
from scripts.s4_optimize import build_portfolio

target_weights = build_portfolio(
    combined_scores, prices_basic,
    num_positions=NUM_POSITIONS,
    optimizer_type=OPTIMIZER_TYPE,
    factor_detail=factor_detail,
)

target_weights.to_csv(LIVE_DIR / "target_portfolio_latest.csv", header=True)
print(f"\nPortfolio: {len(target_weights)} positions")

# %% [markdown]
# ---
# ## Section 5: Backtesting

# %%
from scripts.s5_backtest import run_backtest

results = run_backtest(
    prices_basic, combined_scores,
    rebalance_frequency=REBALANCE_FREQ,
    num_positions=NUM_POSITIONS,
)

# %% [markdown]
# ---
# ## Section 6: Trade Recommendations
#
# Connects to IB, pulls live positions, generates trade plan with $70k cash reserve.

# %%
from scripts.s6_trades import generate_trades

trades = generate_trades(
    target_weights, LIVE_DIR,
    combined_scores=combined_scores,
    ib_host=IB_HOST, ib_port=IB_PORT,
)

if trades:
    import pandas as pd
    pd.DataFrame(trades)

# %% [markdown]
# ---
#
# **Next step:** Open `02_execute_trades.ipynb` to review, edit, and execute the trade plan.
