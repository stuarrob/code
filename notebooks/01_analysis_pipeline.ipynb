# %% [markdown]
# # ETF Analysis Pipeline
#
# Three cells:
# 1. **Setup** — paths, parameters, IB settings
# 2. **Analysis** — universe, data, factors, optimization, backtest
# 3. **Trade Plan** — connect to IB, compare target vs live, generate trades
#
# Output: `~/trading/live_portfolio/trade_plan.csv` → used by `02_execute_trades.ipynb`

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import warnings
from pathlib import Path

import nest_asyncio
nest_asyncio.apply()
warnings.filterwarnings("ignore")

# Resolve project root reliably regardless of kernel cwd
if "__vsc_ipynb_file__" in dir():
    PROJECT_ROOT = Path(__vsc_ipynb_file__).resolve().parent.parent
elif Path.cwd().name == "notebooks":
    PROJECT_ROOT = Path.cwd().parent
else:
    PROJECT_ROOT = Path.cwd()

sys.path.insert(0, str(PROJECT_ROOT / "src"))
sys.path.insert(0, str(PROJECT_ROOT / "notebooks"))
sys.path.insert(0, str(PROJECT_ROOT))

DATA_DIR = Path.home() / "trade_data" / "ETFTrader"
RAW_DIR = DATA_DIR / "raw"
PROCESSED_DIR = DATA_DIR / "processed"
IB_CACHE_DIR = DATA_DIR / "ib_historical"
LIVE_DIR = Path.home() / "trading" / "live_portfolio"

for d in [PROCESSED_DIR, LIVE_DIR, IB_CACHE_DIR]:
    d.mkdir(parents=True, exist_ok=True)

# ── Strategy parameters ───────────────────────────────────
FACTOR_WEIGHTS = {
    "momentum": 0.35, "quality": 0.30,
    "value": 0.15, "volatility": 0.20,
}
NUM_POSITIONS = 30
OPTIMIZER_TYPE = "mvo"
REBALANCE_FREQ = "quarterly"

# ── Cash deployment ────────────────────────────────────────
# Set DEPLOY_CASH to deploy a specific amount of additional cash.
# Set to None to use the default cash_reserve mode ($70k held back).
DEPLOY_CASH = 60_000

# IB settings
IB_HOST = "127.0.0.1"
IB_PORT = 4001
IB_CLIENT_ID = 5

print(f"Project:    {PROJECT_ROOT}")
print(f"Data:       {DATA_DIR}")
print(f"Output:     {LIVE_DIR}")
print(f"Positions:  {NUM_POSITIONS}")
print(f"Optimizer:  {OPTIMIZER_TYPE}")
print(f"Rebalance:  {REBALANCE_FREQ}")
if DEPLOY_CASH is not None:
    print(f"Deploy:     ${DEPLOY_CASH:,.0f} additional cash")
else:
    print(f"Deploy:     auto (NLV-based, $70k reserve)")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Project:    /home/stuar/code/ETFTrader
# Data:       /home/stuar/trade_data/ETFTrader
# Output:     /home/stuar/trading/live_portfolio
# Positions:  30
# Optimizer:  mvo
# Rebalance:  quarterly
# Deploy:     $100,000 additional cash

# %% [markdown]
# ---
# ## Analysis
#
# Runs: universe discovery → data collection → factor scoring → portfolio optimization → backtest.

# %%
# ── 1. Universe Discovery ─────────────────────────────────
from scripts.s1_universe import discover_universe
all_tickers, categories, universe_df = discover_universe(PROJECT_ROOT)
print(f"Universe: {len(all_tickers)} ETFs\n")

# ── 2. Data Collection ────────────────────────────────────
RUN_COLLECTION = False  # Set True to update prices via Databento

from scripts.s2_collect import collect_data, apply_quality_filter
prices = collect_data(
    tickers=all_tickers,
    cache_dir=IB_CACHE_DIR,
    processed_dir=PROCESSED_DIR,
    run_collection=RUN_COLLECTION,
)
if prices is not None:
    prices = apply_quality_filter(prices)
    print(f"Prices: {prices.shape[1]} tickers x {prices.shape[0]} days\n")

# ── 3. Factor Scoring ─────────────────────────────────────
from scripts.s3_factors import score_factors
combined_scores, prices_basic, factor_detail = score_factors(
    prices, factor_weights=FACTOR_WEIGHTS,
    categories=categories, raw_dir=RAW_DIR,
)
print(f"Scores: {len(combined_scores)} tickers\n")

# ── 4. Portfolio Optimization ─────────────────────────────
from scripts.s4_optimize import build_portfolio
target_weights = build_portfolio(
    combined_scores, prices_basic,
    num_positions=NUM_POSITIONS,
    optimizer_type=OPTIMIZER_TYPE,
    factor_detail=factor_detail,
)
target_weights.to_csv(LIVE_DIR / "target_portfolio_latest.csv", header=True)
print(f"\nTarget portfolio: {len(target_weights)} positions")
print(f"Saved: {LIVE_DIR / 'target_portfolio_latest.csv'}\n")

# ── 5. Backtest ──────────────────────────────────────────
from scripts.s5_backtest import run_backtest
results = run_backtest(
    prices_basic, combined_scores,
    rebalance_frequency=REBALANCE_FREQ,
    num_positions=NUM_POSITIONS,
)
# Out:
# Full universe: 5042 ETFs
#   Categorized (curated):  792
#   Uncategorized (NASDAQ): 4250
#   Leveraged/inverse:      75 (kept for data collection)
# Universe: 5042 ETFs
#
# Loaded prices: 3932 tickers x 1298 days
#   Range: 2021-02-16 to 2026-04-16
# No data returned for batch of 40 tickers (start=2026-02-14)
# No data returned for batch of 2 tickers (start=2026-02-19)
# No data returned for batch of 7 tickers (start=2026-02-20)
# No data returned for batch of 9 tickers (start=2026-02-21)
# No data returned for batch of 6 tickers (start=2026-02-24)
# No data returned for batch of 2 tickers (start=2026-02-26)
# No data returned for batch of 4 tickers (start=2026-02-27)
# No data returned for batch of 2 tickers (start=2026-02-28)
# No data returned for batch of 1 tickers (start=2026-03-04)
# No data returned for batch of 2 tickers (start=2026-03-05)
# No data returned for batch of 1 tickers (start=2026-03-06)
# No data returned for batch of 5 tickers (start=2026-03-07)
# No data returned for batch of 8 tickers (start=2026-03-10)
# No data returned for batch of 4 tickers (start=2026-03-11)
# No data returned for batch of 3 tickers (start=2026-03-12)
# No data returned for batch of 8 tickers (start=2026-03-13)
# No data returned for batch of 5 tickers (start=2026-03-14)
# No data returned for batch of 10 tickers (start=2026-03-17)
# No data returned for batch of 3 tickers (start=2026-03-18)
# No data returned for batch of 3 tickers (start=2026-03-19)
# No data returned for batch of 7 tickers (start=2026-03-20)
# No data returned for batch of 10 tickers (start=2026-03-21)
# No data returned for batch of 2 tickers (start=2026-03-24)
# No data returned for batch of 12 tickers (start=2026-03-25)
# No data returned for batch of 4 tickers (start=2026-03-26)
# No data returned for batch of 8 tickers (start=2026-03-27)
# No data returned for batch of 11 tickers (start=2026-03-28)
# No data returned for batch of 13 tickers (start=2026-03-31)
# No data returned for batch of 13 tickers (start=2026-04-01)
# No data returned for batch of 14 tickers (start=2026-04-02)
# No data returned for batch of 19 tickers (start=2026-04-03)
# No data returned for batch of 25 tickers (start=2026-04-07)
# No data returned for batch of 32 tickers (start=2026-04-08)
# No data returned for batch of 25 tickers (start=2026-04-09)
# No data returned for batch of 50 tickers (start=2026-04-10)
# No data returned for batch of 68 tickers (start=2026-04-11)
# No data returned for batch of 117 tickers (start=2026-04-14)
# No data returned for batch of 136 tickers (start=2026-04-15)
# No data returned for batch of 314 tickers (start=2026-04-16)
# Quality filter: 3932 -> 2076 tickers
# Date range: 2021-02-16 to 2026-04-16
# Trading days: 1298
# Prices: 2076 tickers x 1298 days
#
# Filtered out 70 leveraged ETFs: AGQ, BOIL, BULZ, CURE, DDM, DRV, DUST, DXD, EDZ, ERX and 60 more
# Basic model: 2006 tickers (70 leveraged/inverse excluded)
# Calculating factors...
#   Momentum:   2006 tickers
#   Quality:    2005 tickers
#   Value:      SKIPPED (no expense ratio data available)
#               Redistributing weight to remaining factors
#               Adjusted weights: momentum=41%, quality=35%, volatility=24%
#   Volatility: 2006 tickers
#
# Integrated scores: 2006 tickers
# Active factors: momentum, quality, volatility (weights: 41%, 35%, 24%)
# Scores: 2006 tickers
#
# Optimizer: MVO, Positions: 30
#
# Portfolio: 30 positions
# Max weight: 7.1%
# Min weight: 3.0%
# HHI: 0.0363
# Expected vol: 13.1%
#
# ──────────────────────────────────────────────────────────────────────────────────────────
#  #  Ticker  Weight  Name                                        Momen  Quali  Volat
# ──────────────────────────────────────────────────────────────────────────────────────────
#  1  FYLD     7.1%  Cambria Foreign Shareholder Yield ETF        91%   100%    62%
#  2  LVHI     6.9%  Franklin International Low Volatility H...   83%    98%    72%
#  3  DMCY     3.8%  Democracy International Fund                 79%    86%    83%
#  4  SDIV     3.6%  Global X SuperDividend ETF                   85%    96%    61%
#  5  EFAS     3.1%  Global X MSCI SuperDividend EAFE ETF         85%    96%    59%
#  6  DVYA     3.2%  iShares Asia/Pacific Dividend ETF            90%    99%    51%
#  7  WLDR     3.3%  Affinity World Leaders Equity ETF            90%    97%    52%
#  8  GCOW     3.0%  Pacer Global Cash Cows Dividend ETF          80%    88%    66%
#  9  GDMA     3.0%  Gadsden Dynamic Multi-Asset ETF              82%    83%    68%
# 10  VIDI     3.0%  Vident International Equity Strategy ETF     89%    99%    44%
# 11  RODM     3.0%  Hartford Multifactor Developed Markets ...   76%    94%    63%
# 12  FGD      3.0%  First Trust Dow Jones Global Select Div...   86%    97%    47%
# 13  INEQ     3.0%  Columbia International Equity Income ETF     81%    93%    55%
# 14  ICOW     3.0%  Pacer Developed Markets International C...   87%    95%    46%
# 15  IDOG     3.0%  ALPS International Sector Dividend Dogs...   83%    92%    51%
# 16  HERD     3.0%  Pacer Cash Cows Fund of Funds ETF            79%    81%    67%
# 17  EWH      3.0%  iShares MSCI Hong Kong ETF                   89%    86%    48%
# 18  VLUE     3.0%  iShares MSCI USA Value Factor ETF            90%    96%    41%
# 19  INCE     3.0%  Franklin Income Equity Focus ETF             68%    86%    78%
# 20  SCDL     3.0%  ETRACS 2x Leveraged US Dividend Factor ...   92%    69%    63%
# 21  LOPP     3.0%  Gabelli Love Our Planet & People ETF         86%    80%    57%
# 22  PVAL     3.0%  Putnam Focused Large Cap Value ETF           73%    86%    65%
# 23  VYMI     3.0%  Vanguard Intl High Dividend Yield ETF        81%    96%    47%
# 24  DBAW     3.0%  Xtrackers MSCI All World ex US Hedged E...   79%    93%    50%
# 25  FAAR     3.0%  First Trust Alternative Absolute Return...   88%    83%    48%
# 26  DEW      3.0%  WisdomTree Global High Dividend Fund         70%    85%    70%
# 27  FIDI     3.0%  Fidelity International High Dividend ETF     79%    88%    52%
# 28  HAP      3.0%  VanEck Natural Resources ETF                 92%    97%    34%
# 29  FDRR     3.0%  Fidelity Dividend ETF for Rising Rates       70%    84%    69%
# 30  VWID     3.0%  Virtus WMC International Dividend ETF        78%    75%    66%
# ──────────────────────────────────────────────────────────────────────────────────────────
# Factor columns show percentile rank vs full universe (higher = better)
#
# Target portfolio: 30 positions
# Saved: /home/stuar/trading/live_portfolio/target_portfolio_latest.csv
#
# Running backtest (HISTORICAL SIMULATION)...
#   Period:     2021-02-16 to 2026-04-16
#   Rebalance:  quarterly
#   Stop-loss:  12%
#   Drift:      5%
#   Capital:    $1,000,000
# Stop-loss triggered for EWH on 2021-11-30: sold 1365.59 shares @ $19.55
# Stop-loss triggered for SDIV on 2022-03-02: sold 1953.70 shares @ $21.11
# Stop-loss triggered for DMCY on 2022-06-13: sold 2197.40 shares @ $19.37
# Stop-loss triggered for DVYA on 2022-06-14: sold 1449.85 shares @ $26.64
# Stop-loss triggered for VIDI on 2022-07-05: sold 1837.46 shares @ $18.35
# Stop-loss triggered for ICOW on 2022-07-14: sold 1330.12 shares @ $22.07
# Stop-loss triggered for RODM on 2022-09-01: sold 1547.12 shares @ $21.04
# Stop-loss triggered for INEQ on 2022-09-20: sold 1625.29 shares @ $18.81
# Stop-loss triggered for FYLD on 2022-09-23: sold 2536.11 shares @ $17.86
# Stop-loss triggered for EFAS on 2022-09-23: sold 4049.01 shares @ $9.57
# Stop-loss triggered for IDOG on 2022-09-23: sold 1493.93 shares @ $18.80
# Stop-loss triggered for VWID on 2022-09-23: sold 942.48 shares @ $18.37
# Stop-loss triggered for FGD on 2022-09-26: sold 2123.01 shares @ $15.41
# Stop-loss triggered for VYMI on 2022-09-26: sold 503.00 shares @ $45.26
# Stop-loss triggered for FIDI on 2022-09-27: sold 1466.31 shares @ $13.46
# Stop-loss triggered for DBAW on 2022-09-29: sold 973.44 shares @ $22.67
# Stop-loss triggered for EWH on 2022-10-24: sold 1702.05 shares @ $14.35
# Stop-loss triggered for LOPP on 2023-10-27: sold 1135.45 shares @ $20.90
# ──────────────────────────────────────────────────
# BACKTEST RESULTS (historical simulation)
# ──────────────────────────────────────────────────
#   CAGR:              10.7%
#   Sharpe:            0.58
#   Sortino:           0.82
#   Max Drawdown:      -19.1%
#   Volatility:        11.8%
#   Total Return:      69.3%
#   Rebalances:        2 (0.4/year)
#   Win Rate:          55%
#
#   Stop-loss events:  18 (historical)
# ──────────────────────────────────────────────────
#
#   NOTE: 18 stop-loss events occurred DURING
#   the backtest (mostly the 2022 drawdown).
#   They show how the strategy protects capital.
#   They do NOT affect today's target portfolio.

# %% [markdown]
# ---
# ## Trade Plan
#
# Connects to IB, compares target portfolio vs live positions, generates trades.
# Shows a position comparison table and validates: long-only, no margin.
#
# Output: `trade_plan.csv` and `portfolio_state.json` for `02_execute_trades.ipynb`.

# %%
import pandas as pd
from scripts.s6_trades import cleanup_account, generate_trades, write_portfolio_state

# Phase 1: Clean up the account (cancel orders, cover shorts)
print("=" * 60)
print("PHASE 1: Account Cleanup")
print("=" * 60)
cleanup = cleanup_account(
    ib_host=IB_HOST, ib_port=IB_PORT,
    ib_client_id=IB_CLIENT_ID + 1,
)

# Phase 2: Generate trade plan
print("\n" + "=" * 60)
print("PHASE 2: Generate Trade Plan")
print("=" * 60)
trades, context = generate_trades(
    target_weights, LIVE_DIR,
    combined_scores=combined_scores,
    ib_host=IB_HOST, ib_port=IB_PORT,
    ib_client_id=IB_CLIENT_ID,
    deploy_cash=DEPLOY_CASH,
    return_context=True,
)

# Phase 3: Write state file (contract for notebook 2)
if trades:
    print("\n" + "=" * 60)
    print("PHASE 3: Write Portfolio State")
    print("=" * 60)
    state_file = write_portfolio_state(
        cleanup_result=cleanup,
        trades=trades,
        target_weights=target_weights,
        live_dir=LIVE_DIR,
        deploy_cash=DEPLOY_CASH,
        sizing_basis=context.get("sizing_basis"),
        ib_positions=context.get("ib_positions"),
        live_prices=context.get("live_prices"),
        cash=context.get("cash"),
        nlv=context.get("nlv"),
        account=context.get("account"),
    )
    print(f"\nNext step: Open 02_execute_trades.ipynb")
    pd.DataFrame(trades)
else:
    print("\nNo trades generated. Nothing to execute.")
# Out:
# ============================================================
# PHASE 1: Account Cleanup
# ============================================================
# Connected for cleanup: U9544585
#   No open orders to cancel
#
# ──────────────────────────────────────────────────
# CLEANUP COMPLETE
#   Orders cancelled: 0
#   Shorts covered:   0
#   Remaining orders: 0
#   Remaining shorts: 0
#   Cash after:       $161,422
#   NLV after:        $367,495
# ──────────────────────────────────────────────────
#
# ============================================================
# PHASE 2: Generate Trade Plan
# ============================================================
# Connected: U9544585
# Error 200, reqId 6: No security definition has been found for the request, contract: Stock(symbol='DMCY', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='DMCY', exchange='SMART', currency='USD')
# Error 200, reqId 34: No security definition has been found for the request, contract: Stock(symbol='VWID', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='VWID', exchange='SMART', currency='USD')
# Excluding 2 untradeable ticker(s) from target: DMCY, VWID
# Prices: 31 from IB (all live)
#
# Account: NLV=$367,495  Cash=$161,422  Invested=$205,586
# Deploy mode: deploying $100,000 additional cash
# Sizing basis: $305,586 (invested + deploy_cash)
# Positions: 27  |  Live prices: 31
#
# Cash flow: cash=$161,422 + sells=$15,663 - covers=$0 = $177,085
# Available for buys: $100,000
#
# Plan validated: projected cash=$77,105 (long-only, no margin)
#
# ==============================================================================
# PORTFOLIO REBALANCE SUMMARY
# ==============================================================================
#                CURRENT        TARGET    ACTION   SHARES       VALUE
#   ──────  ────────────  ────────────  ────────  ───────  ──────────
#     DBAW    $    7,897          3.2%       BUY       42   $   1,928
#      DEW    $    7,741          3.2%       BUY       30   $   2,037
#      DTH    $    7,815             —      SELL      138   $   7,815
#     DVYA    $    5,651          3.4%      HOLD
#     ECOW    $    7,848             —      SELL      279   $   7,848
#     EFAS    $    6,060          3.3%       BUY      188   $   4,098
#      EWH    $    7,788          3.2%       BUY       87   $   2,047
#     FAAR             —          3.2%       BUY      294   $   9,828
#     FDRR             —          3.2%       BUY      155   $   9,802
#      FGD    $    7,871          3.2%       BUY       58   $   1,934
#     FIDI    $    7,801          3.2%       BUY       71   $   2,021
#     FYLD    $   17,637          7.6%       BUY      148   $   5,625
#     GCOW    $    7,759          3.2%       BUY       45   $   2,066
#     GDMA    $    7,920          3.2%       BUY       45   $   1,896
#      HAP    $    4,205          3.2%      HOLD
#     HERD    $    7,880          3.2%       BUY       41   $   1,946
#     ICOW    $    4,324          3.2%       BUY      124   $   5,471
#     IDOG    $    7,828          3.2%       BUY       46   $   2,001
#     INCE    $    7,840          3.2%       BUY       29   $   1,927
#     INEQ    $    5,300          3.2%       BUY      111   $   4,525
#     LOPP    $    7,655          3.2%       BUY       60   $   2,177
#     LVHI    $   17,626          7.4%       BUY      122   $   4,978
#     PVAL             —          3.2%       BUY      199   $   9,807
#     RODM    $    7,839          3.2%       BUY       48   $   1,980
#     SCDL             —          3.2%       BUY      198   $   9,817
#     SDIV    $    5,784          3.9%       BUY      230   $   6,019
#     VIDI    $    3,708          3.2%      HOLD
#     VLUE    $    7,928          3.2%       BUY       12   $   1,903
#     VYMI    $    7,823          3.2%       BUY       20   $   2,006
#     WLDR    $    8,641          3.5%       BUY       53   $   2,140
#   ──────  ────────────  ────────────  ────────  ───────  ──────────
#
#   Sells: 2 trades, $15,663
#   Buys:  25 trades, $99,981
#   Cash now:   $     161,422
#   Cash after: $      77,105
#
#   LONG-ONLY, NO MARGIN
# ==============================================================================
# Saved: /home/stuar/trading/live_portfolio/trade_plan.csv
#
# ──────────────────────────────────────────────────────────────────────
# PORTFOLIO TRANSITION SUMMARY
# ──────────────────────────────────────────────────────────────────────
#   Retained:  24 positions (already held & still in target)
#   Exiting:   2 positions (held but no longer in target)
#   Entering:  4 positions (new to portfolio)
#
#   SELLS (2):
#     DTH    $     7,815  WisdomTree International High Divid
#     ECOW   $     7,848  Pacer Emerging Markets Cash Cows 10
#
#   BUYS (25):
#     DBAW   $     1,928  Xtrackers MSCI All World ex US Hedg  (score rank: 99%)
#     DEW    $     2,037  WisdomTree Global High Dividend Fun  (score rank: 99%)
#     EFAS   $     4,098  Global X MSCI SuperDividend EAFE ET  (score rank: 100%)
#     EWH    $     2,047  iShares MSCI Hong Kong ETF  (score rank: 99%)
#     FAAR   $     9,828  First Trust Alternative Absolute Re  (score rank: 99%)
#     FDRR   $     9,802  Fidelity Dividend ETF for Rising Ra  (score rank: 99%)
#     FGD    $     1,934  First Trust Dow Jones Global Select  (score rank: 99%)
#     FIDI   $     2,021  Fidelity International High Dividen  (score rank: 99%)
#     FYLD   $     5,625  Cambria Foreign Shareholder Yield E  (score rank: 100%)
#     GCOW   $     2,066  Pacer Global Cash Cows Dividend ETF  (score rank: 100%)
#     GDMA   $     1,896  Gadsden Dynamic Multi-Asset ETF  (score rank: 100%)
#     HERD   $     1,946  Pacer Cash Cows Fund of Funds ETF  (score rank: 99%)
#     ICOW   $     5,471  Pacer Developed Markets Internation  (score rank: 99%)
#     IDOG   $     2,001  ALPS International Sector Dividend   (score rank: 99%)
#     INCE   $     1,927  Franklin Income Equity Focus ETF  (score rank: 99%)
#     INEQ   $     4,525  Columbia International Equity Incom  (score rank: 99%)
#     LOPP   $     2,177  Gabelli Love Our Planet & People ET  (score rank: 99%)
#     LVHI   $     4,978  Franklin International Low Volatili  (score rank: 100%)
#     PVAL   $     9,807  Putnam Focused Large Cap Value ETF  (score rank: 99%)
#     RODM   $     1,980  Hartford Multifactor Developed Mark  (score rank: 100%)
#     SCDL   $     9,817  ETRACS 2x Leveraged US Dividend Fac  (score rank: 99%)
#     SDIV   $     6,019  Global X SuperDividend ETF  (score rank: 100%)
#     VLUE   $     1,903  iShares MSCI USA Value Factor ETF  (score rank: 99%)
#     VYMI   $     2,006  Vanguard Intl High Dividend Yield E  (score rank: 99%)
#     WLDR   $     2,140  Affinity World Leaders Equity ETF  (score rank: 100%)
# ──────────────────────────────────────────────────────────────────────
#
# ============================================================
# PHASE 3: Write Portfolio State
# ============================================================
# Portfolio state written: /home/stuar/trading/live_portfolio/portfolio_state.json
#   Pre-trade positions:  27
#   Planned trades:       27
#   Expected positions:   29
#   Expected cash:        $77,105
#
# Next step: Open 02_execute_trades.ipynb
